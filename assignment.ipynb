# %%
import pandas as pd

df = pd.read_csv('student_habits_performance.csv')
print("First 5 rows of the dataset:")
print(df.head())
# Out:
# First 5 rows of the dataset:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# ...

# %%
import pandas as pd

df = pd.read_csv('student_habits_performance.csv')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
# ...

# %%
import pandas as pd

df = pd.read_csv('student_habits_performance.csv')
print(df.isnull().sum())
# Out:
# student_id                        0
# age                               0
# gender                            0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# part_time_job                     0
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      0
# exercise_frequency                0
# parental_education_level         91
# internet_quality                  0
# mental_health_rating              0
# extracurricular_participation     0
# exam_score                        0
# dtype: int64

# %%
import pandas as pd

df = pd.read_csv('student_habits_performance.csv')
print(df.describe())
# Out:
#              age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  1000.0000           1000.00000         1000.000000    1000.000000
# mean     20.4980              3.55010            2.505500       1.819700
# std       2.3081              1.46889            1.172422       1.075118
# min      17.0000              0.00000            0.000000       0.000000
# 25%      18.7500              2.60000            1.700000       1.000000
# 50%      20.0000              3.50000            2.500000       1.800000
# 75%      23.0000              4.50000            3.300000       2.525000
# max      24.0000              8.30000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count            1000.000000  1000.000000         1000.000000
# mean               84.131700     6.470100            3.042000
# std                 9.399246     1.226377            2.025423
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
plt.plot(df['student_id'], df['exam_score'], marker='o', linestyle='-', color='blue')
plt.title("Exam Score Trend Across Students")
plt.xlabel("Student ID")
plt.ylabel("Exam Score")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.barplot(x='gender', y='exam_score', data=df, estimator='mean', palette='Set2')
plt.title("Average Exam Score by Gender")
plt.ylabel("Average Exam Score")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.scatterplot(x='sleep_hours', y='exam_score', hue='gender', data=df, palette='Set1')
plt.title("Sleep Hours vs Exam Score")
plt.xlabel("Sleep Hours")
plt.ylabel("Exam Score")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.histplot(df['gaming_hours'], bins=10, kde=True, color='purple')
plt.title("Distribution of Gaming Hours")
plt.xlabel("Gaming Hours")
plt.tight_layout()
plt.show()

# %%
print(df.groupby('gender')['exam_score'].mean())
# Out:
# gender
# Female    69.741372
# Male      69.368344
# Other     70.647619
# Name: exam_score, dtype: float64

# %%
print(df.groupby('gender')['sleep_hours'].mean())
# Out:
# gender
# Female    6.471726
# Male      6.438994
# Other     6.804762
# Name: sleep_hours, dtype: float64
